# %%
import pandas as pd
# Out:
# C:\Users\10698046\AppData\Local\Temp\ipykernel_18720\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("Youtube_Data.csv")

# %%
df.head()
# Out:
#    SFDC_OPPORTUNITY_CONTENT_SUBMISSION_METRICS_ID  \
# 0                                       514918358
# 1                                       514918362
# 2                                       514918363
# 3                                       514918369
# 4                                       514918373
#
#                           SRC_METRIC_ID  SRC_OPPORTUNITY_ID  \
# 0  ad13cf8c-2071-48f1-818b-2bd6f7f20061  a0M4x00000ZribuEAB
# 1  61e7bb1e-28ed-42cc-8f43-9398010c09f3  a0M4x00000Zre6GEAR
# 2  3a9d96db-5466-4493-96f7-0f5c07029a8f  a0M4x00000bM8NQEA0
# 3  b27d226c-ed25-49a5-ba1b-b31a483caba4  a0M4x00000bM8NQEA0
# 4  19a679f5-cdd4-4add-b248-0fe2f2fdf818  a0M4x00000ZribuEAB
#
#        SRC_CREATOR_ID  SRC_PARTICIPANT_ID SRC_OPPORTUNITY_MANAGER_ID  \
# 0  0014x00000dwPRZAA2  a0Y4x00000cYKdIEAW         0054x000007J1SWAA0
# 1  0014x00000eg8utAAA  a0Y4x00000cYHJoEAO         0054x000005pxOvAAI
# 2  0014x00000dwPVFAA2  a0Y4x00000ekL21EAE         0054x000004RPRaAAO
# ...

# %%
print(df.shape)
print(df.columns)
# Out:
# (21370, 58)
# Index(['SFDC_OPPORTUNITY_CONTENT_SUBMISSION_METRICS_ID', 'SRC_METRIC_ID',
#        'SRC_OPPORTUNITY_ID', 'SRC_CREATOR_ID', 'SRC_PARTICIPANT_ID',
#        'SRC_OPPORTUNITY_MANAGER_ID', 'SRC_CONTENT_ID', 'SRC_EXTERNAL_ID',
#        'OPPORTUNITY_NAME', 'FRANCHISE_NAME', 'GAME_NAME', 'CREATOR_NAME',
#        'CREATOR_USERNAME', 'CREATOR_CHANNEL_TYPE', 'CREATOR_CHANNEL_NAME',
#        'OPPORTUNITY_MANAGER_NAME', 'CONTENT_TITLE', 'CONTENT_URL',
#        'CONTENT_TYPE', 'CONTENT_REVIEW_STATUS', 'OPPORTUNITY_CREATED_DTTM_GMT',
#        'REGISTRATION_START_DTTM_GMT', 'REGISTRATION_END_DTTM_GMT',
#        'EVENT_START_DTTM_GMT', 'EVENT_END_DTTM_GMT',
#        'CONTENT_SUBMISSION_START_DTTM_GMT', 'CONTENT_SUBMISSION_END_DTTM_GMT',
#        'CONTENT_UPLOAD_DTTM_GMT', 'CONTENT_SUBMISSION_DTTM_GMT',
#        'METRICS_CAPTURED_DTTM_GMT', 'SUBMISSION_LIMIT', 'COUNT_VIEWS',
#        'COUNT_LIKES', 'COUNT_DISLIKES', 'COUNT_COMMENTS', 'COUNT_SHARES',
# ...

# %%
print(df.dtypes)
print(df.info())
# Out:
# SFDC_OPPORTUNITY_CONTENT_SUBMISSION_METRICS_ID      int64
# SRC_METRIC_ID                                      object
# SRC_OPPORTUNITY_ID                                 object
# SRC_CREATOR_ID                                     object
# SRC_PARTICIPANT_ID                                 object
# SRC_OPPORTUNITY_MANAGER_ID                         object
# SRC_CONTENT_ID                                     object
# SRC_EXTERNAL_ID                                    object
# OPPORTUNITY_NAME                                   object
# FRANCHISE_NAME                                     object
# GAME_NAME                                          object
# CREATOR_NAME                                       object
# CREATOR_USERNAME                                   object
# CREATOR_CHANNEL_TYPE                               object
# CREATOR_CHANNEL_NAME                               object
# OPPORTUNITY_MANAGER_NAME                           object
# ...

# %%
print(df.head())
# Out:
#    SFDC_OPPORTUNITY_CONTENT_SUBMISSION_METRICS_ID  \
# 0                                       514918358
# 1                                       514918362
# 2                                       514918363
# 3                                       514918369
# 4                                       514918373
#
#                           SRC_METRIC_ID  SRC_OPPORTUNITY_ID  \
# 0  ad13cf8c-2071-48f1-818b-2bd6f7f20061  a0M4x00000ZribuEAB
# 1  61e7bb1e-28ed-42cc-8f43-9398010c09f3  a0M4x00000Zre6GEAR
# 2  3a9d96db-5466-4493-96f7-0f5c07029a8f  a0M4x00000bM8NQEA0
# 3  b27d226c-ed25-49a5-ba1b-b31a483caba4  a0M4x00000bM8NQEA0
# 4  19a679f5-cdd4-4add-b248-0fe2f2fdf818  a0M4x00000ZribuEAB
#
#        SRC_CREATOR_ID  SRC_PARTICIPANT_ID SRC_OPPORTUNITY_MANAGER_ID  \
# 0  0014x00000dwPRZAA2  a0Y4x00000cYKdIEAW         0054x000007J1SWAA0
# 1  0014x00000eg8utAAA  a0Y4x00000cYHJoEAO         0054x000005pxOvAAI
# 2  0014x00000dwPVFAA2  a0Y4x00000ekL21EAE         0054x000004RPRaAAO
# ...

# %%
print(df.columns)
# Out:
# Index(['SFDC_OPPORTUNITY_CONTENT_SUBMISSION_METRICS_ID', 'SRC_METRIC_ID',
#        'SRC_OPPORTUNITY_ID', 'SRC_CREATOR_ID', 'SRC_PARTICIPANT_ID',
#        'SRC_OPPORTUNITY_MANAGER_ID', 'SRC_CONTENT_ID', 'SRC_EXTERNAL_ID',
#        'OPPORTUNITY_NAME', 'FRANCHISE_NAME', 'GAME_NAME', 'CREATOR_NAME',
#        'CREATOR_USERNAME', 'CREATOR_CHANNEL_TYPE', 'CREATOR_CHANNEL_NAME',
#        'OPPORTUNITY_MANAGER_NAME', 'CONTENT_TITLE', 'CONTENT_URL',
#        'CONTENT_TYPE', 'CONTENT_REVIEW_STATUS', 'OPPORTUNITY_CREATED_DTTM_GMT',
#        'REGISTRATION_START_DTTM_GMT', 'REGISTRATION_END_DTTM_GMT',
#        'EVENT_START_DTTM_GMT', 'EVENT_END_DTTM_GMT',
#        'CONTENT_SUBMISSION_START_DTTM_GMT', 'CONTENT_SUBMISSION_END_DTTM_GMT',
#        'CONTENT_UPLOAD_DTTM_GMT', 'CONTENT_SUBMISSION_DTTM_GMT',
#        'METRICS_CAPTURED_DTTM_GMT', 'SUBMISSION_LIMIT', 'COUNT_VIEWS',
#        'COUNT_LIKES', 'COUNT_DISLIKES', 'COUNT_COMMENTS', 'COUNT_SHARES',
# ...

# %%
print(df[['SRC_METRIC_ID','CREATOR_CATEGORY']].head())
# Out:
#                           SRC_METRIC_ID CREATOR_CATEGORY
# 0  ad13cf8c-2071-48f1-818b-2bd6f7f20061          Creator
# 1  61e7bb1e-28ed-42cc-8f43-9398010c09f3          Creator
# 2  3a9d96db-5466-4493-96f7-0f5c07029a8f          Creator
# 3  b27d226c-ed25-49a5-ba1b-b31a483caba4          Creator
# 4  19a679f5-cdd4-4add-b248-0fe2f2fdf818          Creator

# %%
print(df.SRC_METRIC_ID.head())
# Out:
# 0    ad13cf8c-2071-48f1-818b-2bd6f7f20061
# 1    61e7bb1e-28ed-42cc-8f43-9398010c09f3
# 2    3a9d96db-5466-4493-96f7-0f5c07029a8f
# 3    b27d226c-ed25-49a5-ba1b-b31a483caba4
# 4    19a679f5-cdd4-4add-b248-0fe2f2fdf818
# Name: SRC_METRIC_ID, dtype: object

# %%
# get the first row
# python counts from 0
print(df.loc[0])
# Out:
# SFDC_OPPORTUNITY_CONTENT_SUBMISSION_METRICS_ID                                      514918358
# SRC_METRIC_ID                                            ad13cf8c-2071-48f1-818b-2bd6f7f20061
# SRC_OPPORTUNITY_ID                                                         a0M4x00000ZribuEAB
# SRC_CREATOR_ID                                                             0014x00000dwPRZAA2
# SRC_PARTICIPANT_ID                                                         a0Y4x00000cYKdIEAW
# SRC_OPPORTUNITY_MANAGER_ID                                                 0054x000007J1SWAA0
# SRC_CONTENT_ID                                                             a0d4x00000A7rAUAAZ
# SRC_EXTERNAL_ID                                                                   KjUd21OIPBk
# OPPORTUNITY_NAME                                     Castle Estate Kit - Grab a Code + Assets
# FRANCHISE_NAME                                                                       The Sims
# ...

# %%
# get the 100th row
# python counts from 0
print(df.loc[99])
# Out:
# SFDC_OPPORTUNITY_CONTENT_SUBMISSION_METRICS_ID                                         232616
# SRC_METRIC_ID                                            ef75c925-d693-4852-847c-478613871fdb
# SRC_OPPORTUNITY_ID                                                         a0M4x000001WXyHEAW
# SRC_CREATOR_ID                                                             0014x00000dwPuOAAU
# SRC_PARTICIPANT_ID                                                         a0Y4x000000Jo34EAC
# SRC_OPPORTUNITY_MANAGER_ID                                                 0054x000004R2P4AAK
# SRC_CONTENT_ID                                                             a0d4x000003Q0laAAC
# SRC_EXTERNAL_ID                                                                   H-LCFp4aC-4
# OPPORTUNITY_NAME                                        The Sims 4 Eco Lifestyle Early Access
# FRANCHISE_NAME                                                                       The Sims
# ...

# %%
# get the last row
# this will cause an error
#print(df.loc[-]) wont work
print(df.loc[df.shape[0]-1])
# Out:
# SFDC_OPPORTUNITY_CONTENT_SUBMISSION_METRICS_ID                                         45457648
# SRC_METRIC_ID                                              3f21528a-7a59-4429-8727-57d8e2e3f003
# SRC_OPPORTUNITY_ID                                                           a0M4x000001WY0CEAW
# SRC_CREATOR_ID                                                               0014x00000dwPyTAAU
# SRC_PARTICIPANT_ID                                                           a0Y4x000000JpPgEAK
# SRC_OPPORTUNITY_MANAGER_ID                                                   0054x000004R2P4AAK
# SRC_CONTENT_ID                                                               a0d4x000003Q25bAAC
# SRC_EXTERNAL_ID                                                                     PbOU3uUG_8k
# OPPORTUNITY_NAME                                            Apex Season 8 - 10 x Videos/Streams
# FRANCHISE_NAME                                                                     Apex Legends
# ...

# %%
print(df.iloc[-1])
# Out:
# SFDC_OPPORTUNITY_CONTENT_SUBMISSION_METRICS_ID                                         45457648
# SRC_METRIC_ID                                              3f21528a-7a59-4429-8727-57d8e2e3f003
# SRC_OPPORTUNITY_ID                                                           a0M4x000001WY0CEAW
# SRC_CREATOR_ID                                                               0014x00000dwPyTAAU
# SRC_PARTICIPANT_ID                                                           a0Y4x000000JpPgEAK
# SRC_OPPORTUNITY_MANAGER_ID                                                   0054x000004R2P4AAK
# SRC_CONTENT_ID                                                               a0d4x000003Q25bAAC
# SRC_EXTERNAL_ID                                                                     PbOU3uUG_8k
# OPPORTUNITY_NAME                                            Apex Season 8 - 10 x Videos/Streams
# FRANCHISE_NAME                                                                     Apex Legends
# ...

# %%
df.loc[:, ['EVENT_START_DTTM_GMT', 'EVENT_END_DTTM_GMT']]
# Out:
#           EVENT_START_DTTM_GMT       EVENT_END_DTTM_GMT
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 21365                      NaN                      NaN
# 21366                      NaN                      NaN
# 21367                      NaN                      NaN
# 21368  2021-02-02 00:00:00.000  2021-06-05 00:00:00.000
# 21369  2021-02-02 00:00:00.000  2021-06-05 00:00:00.000
#
# [21370 rows x 2 columns]

# %%
df.iloc[:, ::20]
# Out:
#        SFDC_OPPORTUNITY_CONTENT_SUBMISSION_METRICS_ID  \
# 0                                           514918358
# 1                                           514918362
# 2                                           514918363
# 3                                           514918369
# 4                                           514918373
# ...                                               ...
# 21365                                          674748
# 21366                                          674763
# 21367                                        45531162
# 21368                                        45457549
# 21369                                        45457648
#
#       OPPORTUNITY_CREATED_DTTM_GMT  PEAK_CONCURRENT_VIEW
# 0          2024-01-16 17:59:45.000                   NaN
# 1          2023-12-11 11:27:53.000                   NaN
# 2          2023-09-20 19:05:19.000                   NaN
# 3          2023-09-20 19:05:19.000                   NaN
# ...

# %%
print(df.columns)
# Out:
# Index(['SFDC_OPPORTUNITY_CONTENT_SUBMISSION_METRICS_ID', 'SRC_METRIC_ID',
#        'SRC_OPPORTUNITY_ID', 'SRC_CREATOR_ID', 'SRC_PARTICIPANT_ID',
#        'SRC_OPPORTUNITY_MANAGER_ID', 'SRC_CONTENT_ID', 'SRC_EXTERNAL_ID',
#        'OPPORTUNITY_NAME', 'FRANCHISE_NAME', 'GAME_NAME', 'CREATOR_NAME',
#        'CREATOR_USERNAME', 'CREATOR_CHANNEL_TYPE', 'CREATOR_CHANNEL_NAME',
#        'OPPORTUNITY_MANAGER_NAME', 'CONTENT_TITLE', 'CONTENT_URL',
#        'CONTENT_TYPE', 'CONTENT_REVIEW_STATUS', 'OPPORTUNITY_CREATED_DTTM_GMT',
#        'REGISTRATION_START_DTTM_GMT', 'REGISTRATION_END_DTTM_GMT',
#        'EVENT_START_DTTM_GMT', 'EVENT_END_DTTM_GMT',
#        'CONTENT_SUBMISSION_START_DTTM_GMT', 'CONTENT_SUBMISSION_END_DTTM_GMT',
#        'CONTENT_UPLOAD_DTTM_GMT', 'CONTENT_SUBMISSION_DTTM_GMT',
#        'METRICS_CAPTURED_DTTM_GMT', 'SUBMISSION_LIMIT', 'COUNT_VIEWS',
#        'COUNT_LIKES', 'COUNT_DISLIKES', 'COUNT_COMMENTS', 'COUNT_SHARES',
# ...

# %%
print(df.groupby('AVERAGE_VIEW_DURATION')['COUNT_LIKES'].mean())
# Out:
# AVERAGE_VIEW_DURATION
# 0.0       113.336898
# 1.0         8.357143
# 2.0         0.700000
# 3.0         1.400000
# 4.0         0.750000
#              ...
# 5757.0    325.000000
# 5906.0    469.000000
# 6456.0      1.000000
# 7292.0     12.000000
# 9040.0    354.000000
# Name: COUNT_LIKES, Length: 1199, dtype: float64

# %%
for col in df.columns:
    if len(df[col].unique()) in range(3,10):
        print(df[col].unique(),col)
# Out:
# [nan 'Unreviewed' 'Rejected' 'Approved' 'Needs_Approval'] CONTENT_REVIEW_STATUS
# [nan  0.  5.  2.  1.  3.  4.] CONTENT_RATING

# %%
df.groupby(['CONTENT_REVIEW_STATUS','CONTENT_RATING'])[['COUNT_VIEWS','COUNT_LIKES']].mean()
# Out:
#                                         COUNT_VIEWS  COUNT_LIKES
# CONTENT_REVIEW_STATUS CONTENT_RATING
# Approved              0.0              53892.024764  6021.361661
#                       1.0                  1.352941     0.058824
#                       2.0             275468.500000   178.500000
#                       3.0               8810.000000   141.900000
#                       4.0             107101.375000   446.875000
#                       5.0             183154.193548  4890.451613
# Rejected              0.0              78457.133616  2929.597561
#                       2.0             191178.000000  1876.000000
#                       3.0              25364.000000   723.000000
# Unreviewed            0.0              46980.445444  2207.702038

# %%
df.groupby(['CONTENT_REVIEW_STATUS','CONTENT_RATING'])[['COUNT_VIEWS','COUNT_LIKES']].mean().reset_index()
# Out:
#   CONTENT_REVIEW_STATUS  CONTENT_RATING    COUNT_VIEWS  COUNT_LIKES
# 0              Approved             0.0   53892.024764  6021.361661
# 1              Approved             1.0       1.352941     0.058824
# 2              Approved             2.0  275468.500000   178.500000
# 3              Approved             3.0    8810.000000   141.900000
# 4              Approved             4.0  107101.375000   446.875000
# 5              Approved             5.0  183154.193548  4890.451613
# 6              Rejected             0.0   78457.133616  2929.597561
# 7              Rejected             2.0  191178.000000  1876.000000
# 8              Rejected             3.0   25364.000000   723.000000
# 9            Unreviewed             0.0   46980.445444  2207.702038

# %%
df.select_dtypes('number').columns
# Out:
# Index(['SFDC_OPPORTUNITY_CONTENT_SUBMISSION_METRICS_ID', 'SUBMISSION_LIMIT',
#        'COUNT_VIEWS', 'COUNT_LIKES', 'COUNT_DISLIKES', 'COUNT_COMMENTS',
#        'COUNT_SHARES', 'ESTIMATED_MINUTES_WATCHED', 'AVERAGE_VIEW_DURATION',
#        'AVERAGE_VIEW_PERCENTAGE', 'SUBSCRIBERS_GAINED', 'PEAK_CONCURRENT_VIEW',
#        'ENGAGEMENT', 'TOTAL_REACH', 'CONTENT_RATING', 'APPLICANT_STATUS',
#        'APPLICANT_APPROVED_BY', 'APPLICANT_APPROVED_DTTM_GMT',
#        'IS_PHYSICAL_CONTENT'],
#       dtype='object')

# %%
df.groupby('CONTENT_REVIEW_STATUS')['CONTENT_RATING'].nunique()
# Out:
# CONTENT_REVIEW_STATUS
# Approved          6
# Needs_Approval    0
# Rejected          3
# Unreviewed        1
# Name: CONTENT_RATING, dtype: int64

# %%
df.groupby('CONTENT_REVIEW_STATUS')['CONTENT_RATING'].value_counts().reset_index()
# Out:
#   CONTENT_REVIEW_STATUS  CONTENT_RATING  count
# 0              Approved             0.0   8884
# 1              Approved             5.0     31
# 2              Approved             1.0     17
# 3              Approved             3.0     10
# 4              Approved             4.0      8
# 5              Approved             2.0      2
# 6              Rejected             0.0   1886
# 7              Rejected             2.0      1
# 8              Rejected             3.0      1
# 9            Unreviewed             0.0   3336

# %%
import matplotlib.pyplot as plt

# %%
# !pip install matplotlib

# %%
# mean of content views vs content review status
basic_plot=df.groupby('CONTENT_REVIEW_STATUS')['COUNT_VIEWS'].mean()
basic_plot.plot()
# Out:
# <Axes: xlabel='CONTENT_REVIEW_STATUS'>
